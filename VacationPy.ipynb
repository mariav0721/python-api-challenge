# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head(20)
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 0         0  port elizabeth -33.9180   25.5701     14.08        76
# 1         1          uturoa -16.7333 -151.4333     24.31        62
# 2         2         dunedin -45.8742  170.5036      8.78        60
# 3         3       ketchikan  55.3422 -131.6461     18.26        88
# 4         4     kailua-kona  19.6406 -155.9956     31.44        81
# 5         5       vorgashor  67.5833   63.9500     16.99        89
# 6         6         aasiaat  68.7098  -52.8699      3.44        96
# 7         7       adamstown -25.0660 -130.1015     21.20        73
# 8         8         iqaluit  63.7506  -68.5145      6.50        87
# 9         9   seven pagodas  12.6264   80.1722     30.03        59
# 10       10  puerto natales -51.7236  -72.4875     -3.10        96
# 11       11          saipan  15.1355  145.7010     31.39       100
# 12       12        bilibino  68.0546  166.4372     25.28        35
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=1000,
    frame_height=700,
    hover_cols=["Humidity"]
)


# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
ideal_weather_df= city_data_df.loc[(city_data_df['Max Temp']>10)]

ideal_weather_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  port elizabeth -33.9180   25.5701     14.08        76          90
# 1        1          uturoa -16.7333 -151.4333     24.31        62          16
# 3        3       ketchikan  55.3422 -131.6461     18.26        88          75
# 4        4     kailua-kona  19.6406 -155.9956     31.44        81          40
# 5        5       vorgashor  67.5833   63.9500     16.99        89         100
#
#    Wind Speed Country        Date
# 0        2.57      ZA  1689988001
# 1        5.61      PF  1689988001
# 3        3.60      US  1689987771
# 4        5.66      US  1689988002
# 5        3.14      RU  1689988003

# %%
# Narrow down cities that fit criteria and drop any results with null values

second_weather_df = city_data_df.loc[(city_data_df['Max Temp'] > 10) & (city_data_df['Wind Speed'] > 2)]
# YOUR CODE HERE

# Drop any rows with null values
second_weather_df = second_weather_df.dropna()


count=len(second_weather_df['City'].unique())

# This was for me print(count)
# Display sample data
second_weather_df.head(20)
# Out:
#     City_ID                         City      Lat       Lng  Max Temp  \
# 0         0               port elizabeth -33.9180   25.5701     14.08
# 1         1                       uturoa -16.7333 -151.4333     24.31
# 3         3                    ketchikan  55.3422 -131.6461     18.26
# 4         4                  kailua-kona  19.6406 -155.9956     31.44
# 5         5                    vorgashor  67.5833   63.9500     16.99
# 7         7                    adamstown -25.0660 -130.1015     21.20
# 9         9                seven pagodas  12.6264   80.1722     30.03
# 11       11                       saipan  15.1355  145.7010     31.39
# 14       14                      emerald -23.5333  148.1667     20.96
# 15       15                         lebu -37.6167  -73.6500     10.64
# 22       22                         muli   2.9167   73.5667     27.50
# 23       23                       bandol  43.1371    5.7316     25.93
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=second_weather_df.copy()
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 0  port elizabeth      ZA -33.9180   25.5701        76
# 1          uturoa      PF -16.7333 -151.4333        62
# 3       ketchikan      US  55.3422 -131.6461        88
# 4     kailua-kona      US  19.6406 -155.9956        81
# 5       vorgashor      RU  67.5833   63.9500        89

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port elizabeth - nearest hotel: Waterford Hotel
# uturoa - nearest hotel: Hawaiki Nui hotel
# ketchikan - nearest hotel: Cape Fox Lodge
# kailua-kona - nearest hotel: Kona Seaside Hotel
# vorgashor - nearest hotel: София
# adamstown - nearest hotel: No hotel found
# seven pagodas - nearest hotel: Radisson Temple Bay
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# emerald - nearest hotel: Emerald Central Hotel
# lebu - nearest hotel: No hotel found
# muli - nearest hotel: Mulaku
# bandol - nearest hotel: Clairefont
# edinburgh of the seven seas - nearest hotel: No hotel found
# kingston - nearest hotel: Aphrodite Hotel
# ohara - nearest hotel: No hotel found
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# al jawf - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# ...

# %%
#Remove cities where Hotel was not found

hotel_df = hotel_df[hotel_df['Hotel Name'] != 'No hotel found']

hotel_df = hotel_df.reset_index(drop=True)


hotel_df.head(50)
# Out:
#                         City Country      Lat       Lng  Humidity  \
# 0             port elizabeth      ZA -33.9180   25.5701        76
# 1                     uturoa      PF -16.7333 -151.4333        62
# 2                  ketchikan      US  55.3422 -131.6461        88
# 3                kailua-kona      US  19.6406 -155.9956        81
# 4                  vorgashor      RU  67.5833   63.9500        89
# 5              seven pagodas      IN  12.6264   80.1722        59
# 6                     saipan      MP  15.1355  145.7010       100
# 7                    emerald      AU -23.5333  148.1667        37
# 8                       muli      MV   2.9167   73.5667        73
# 9                     bandol      FR  43.1371    5.7316        66
# 10                  kingston      JM  17.9970  -76.7936        77
# 11             mount gambier      AU -37.8333  140.7667        69
# 12              puerto ayora      EC  -0.7393  -90.3518        83
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# Configure the map plot
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=1000,
    frame_height=700,
    hover_cols=["Hotel Name"]
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]
